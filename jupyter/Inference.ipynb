# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
REPO_NAME = "Final-Project"
REPO_PATH = f"/content/drive/MyDrive/CS598/{REPO_NAME}"

# %%
# %cd /content/drive/MyDrive/CS598/Final-Project/
# Out:
# /content/drive/MyDrive/CS598/Final-Project

# %%
pip install pyts captum

# %%
# !python inference.py --device=cuda:0 --batch=1 --checkpoint='saved_best_0.0001_8_5_0.01_big_ablated_True_0.75_1.0_1.0_False_0.0_False_False_False' --model=big_ablated --inference --mask=0.75
# Out:
# 2025-11-19 21:01:21.413437: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763586081.434265   17382 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763586081.440425   17382 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763586081.456147   17382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
