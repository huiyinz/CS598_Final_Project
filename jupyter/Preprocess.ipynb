# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# 1. Install Rust and the necessary toolchain components
# !apt-get install -y rustc cargo

# 2. Upgrade pip and setuptools, as build issues are sometimes related to outdated tools
# !pip install --upgrade pip setuptools
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# rustc is already the newest version (1.75.0+dfsg0ubuntu1~bpo0-0ubuntu0.22.04).
# cargo is already the newest version (1.75.0+dfsg0ubuntu1~bpo0-0ubuntu0.22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# ...

# %%
REPO_NAME = "Final-Project"
REPO_PATH = f"/content/drive/MyDrive/CS598/{REPO_NAME}"
# !pip install -r "{REPO_PATH}/requirements.txt"

# %%
# %cd /content/drive/MyDrive/CS598/Final-Project/preprocess/
# Out:
# /content/drive/MyDrive/CS598/Final-Project/preprocess

# %%
# %cd /content/drive/MyDrive/CS598/Final-Project/data
# Out:
# /content/drive/MyDrive/CS598/Final-Project/data

# %%
import numpy as np

# Path to your .npy file
file_path = './train_intra.npy'

# Load the data
data = np.load(file_path, allow_pickle=True)

# %%
if isinstance(data, np.ndarray) and data.dtype == 'object':
    data = data.item()

# %%
# !pip install wfdb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 97.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# ...

# %%
# !wget https://physionet.org/static/published-projects/iafdb/intracardiac-atrial-fibrillation-database-1.0.0.zip
# !unzip intracardiac-atrial-fibrillation-database-1.0.0

# %%
# !python preprocess_intra.py --path=intracardiac-atrial-fibrillation-database-1.0.0
# Out:
# Directory already exists: ../data
