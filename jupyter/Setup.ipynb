# %%
pip install torch torchvision torchaudio

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
REPO_NAME = "Final-Project"
REPO_URL = "https://github.com/willxxy/Text-EGM.git"
DRIVE_PATH = f"/content/drive/MyDrive/CS598/{REPO_NAME}"

# !mkdir -p "$DRIVE_PATH"

import os
os.chdir(DRIVE_PATH)

# !git clone "$REPO_URL" .
# Out:
# Cloning into '.'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 55 (delta 19), reused 27 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (55/55), 34.34 KiB | 1.27 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
