# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# 1. Install Rust and the necessary toolchain components
# !apt-get install -y rustc cargo

# 2. Upgrade pip and setuptools, as build issues are sometimes related to outdated tools
# !pip install --upgrade pip setuptools
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libstd-rust-1.75 libstd-rust-dev
# Suggested packages:
#   cargo-doc llvm-17 lld-17 clang-17
# The following NEW packages will be installed:
#   cargo libstd-rust-1.75 libstd-rust-dev rustc
# 0 upgraded, 4 newly installed, 0 to remove and 41 not upgraded.
# Need to get 98.1 MB of archives.
# After this operation, 392 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libstd-rust-1.75 amd64 1.75.0+dfsg0ubuntu1~bpo0-0ubuntu0.22.04 [46.3 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libstd-rust-dev amd64 1.75.0+dfsg0ubuntu1~bpo0-0ubuntu0.22.04 [41.6 MB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 rustc amd64 1.75.0+dfsg0ubuntu1~bpo0-0ubuntu0.22.04 [3,404 kB]
# ...

# %%
REPO_NAME = "Final-Project"
REPO_PATH = f"/content/drive/MyDrive/CS598/{REPO_NAME}"
# !pip install -r "{REPO_PATH}/requirements.txt"

# %%
pip install pyts
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 58.9 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/CS598/Final-Project/
# Out:
# /content/drive/MyDrive/CS598/Final-Project

# %%
# !python train.py --device=cuda:0 --batch=8 --patience=5 --model=big_ablated --mask=0.75 --use_ce --epochs 15
# Out:
# 2025-11-19 18:41:01.447844: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 18:41:01.465740: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763577661.487784    9712 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763577661.494290    9712 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
